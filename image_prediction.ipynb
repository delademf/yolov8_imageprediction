# %% [markdown]
# <a href="https://colab.research.google.com/github/delademf/yolov8_imageprediction/blob/main/image_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Downloading** **dependencies**

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %% [markdown]
# **Download yolov8 and predict image from source**

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='/content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4'
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 4 persons, 1 sports ball, 2 tennis rackets, 263.1ms
# video 1/1 (2/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 5 persons, 1 sports ball, 159.9ms
# video 1/1 (3/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 5 persons, 1 sports ball, 156.7ms
# video 1/1 (4/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 5 persons, 1 sports ball, 148.9ms
# video 1/1 (5/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 5 persons, 1 sports ball, 142.1ms
# video 1/1 (6/1205) /content/Poetry In Motion 🎼 Mohammed Kudus #shorts #football (1).mp4: 640x384 7 persons, 1 sports ball, 144.1ms
# ...

# %% [markdown]
# **Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it**

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('/content/runs/pexels-kaique-rocha-109919.jpg')  # predict on an image
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...
